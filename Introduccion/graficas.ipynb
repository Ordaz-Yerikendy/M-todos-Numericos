# %% [markdown]
# # Gráfica de $f(x)=x - 3^{-x}$

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Función cuadrática.
def f(x):
    return x - 3**(-x)
def g(x):
    return x
def h(x):
    return -3**(-x)

# %%
# Valores del eje X que toma el gráfico.
x=np.linspace(-10, 10,100)

# %%
# Graficar ambas funciones.
plt.figure(figsize=(9,5))
plt.plot(x, f(x))
plt.plot (x, g(x))
plt.plot (x, h(x))
plt.axhline(0, color= "green")
plt.axhline(0, color="blue")
plt.axvline(0, color="black")
plt.xlim(-10, 10)
plt.ylim(-5, 5)
plt.grid(color="red")
plt.title("Grafica suma de funcion")
#plt.savefig("output.png") # Guardar gráfico como imágen PNG.
# Mostrarlo.
plt.show()

# %% [markdown]
# Ejercicio 1: Graficar las funciones $x$ y $3^{-x}$ en una sola figura y comentar cómo su resta da origen a la gráfica de $f(x)$.
#
# Ejercicio 2: Agregar título, color, retícula, rótulos a los ejes y aumentar el tamaño de la gráfica.

# %% [markdown]
# En esta práctica aprendí a que programando se puede graficar una función.  Pude lograr graficagraficar las funciones y modificar tamaños de las lineas, colores, agregar títulos y más cosas.
